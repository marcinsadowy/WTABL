# %% [markdown]
# ## TDM TMD

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_wind_speed(x1, x2, x3, z_h, D, C_T, s_x, s_y, U_h0):

    k = 0.4 # Von Karman constant [-]
    z_0lo = 0.0001 # surface rughness length [m]

    ct = (np.pi * C_T * D**2)/(8 * s_x*D * s_y*D)
    #print("ct: ", ct)
    nu_star = 28 * np.sqrt(ct)
    #print("nu_star: ", nu_star)
    beta =  nu_star / (1 + nu_star)
    #print("beta: ", beta)
    z0_WF = z_h * (1 + D/(2 * z_h))**beta * np.exp(-k * (ct + (k/np.log((z_h / z_0lo) * (1 - D/(2 * z_h))**beta))**2)**-0.5)
    #print("z0_WF: ", z0_WF)

    x1 = x1
    x2 = x2
    x3 = x3
    x = np.linspace(x1, x3, x3)

    h1 = np.full_like(x, np.nan, dtype=float)
    h2 = np.full_like(x, np.nan, dtype=float)
    uw = np.full_like(x, np.nan, dtype=float)

    x_h1 = x[x > x1]
    idx_h1 = np.where(x > x1)[0]
    h1[idx_h1] = z0_WF * (z_h/z0_WF + (x_h1 / z0_WF)**0.8)
    h2[x > x2] = ((x[x>x2]-x2)/z0_WF)**(4/5)

    x_h2 = x[x > x2]
    idx_h2 = np.where(x > x2)[0]
    h2[idx_h2] = z0_WF * (0/z0_WF + ((x_h2 - x2) / z0_WF)**0.8)

    # Wind speed profile in zone 1 (deficit)
    idx1 = h1 >= z_h
    uw[idx1] = U_h0 * (
        np.log(h1[idx1] / z_0lo) * np.log(z_h / z0_WF)
    ) / (
        np.log(h1[idx1] / z0_WF) * np.log(z_h / z_0lo)
    )

    # Wind speed profile in zone 2 (recovery)
    idx2 = (x > x2) & (h2 >= z_h)
    uw[idx2] = U_h0 * (
        np.log(h1[idx2] / z_0lo) * np.log(h2[idx2] / z0_WF)
    ) / (
        np.log(h1[idx2] / z0_WF) * np.log(h2[idx2] / z_0lo)
    )

    return x, uw, U_h0

# calculate_wind_speed(x1, x2, x3, z_h, D, ct, s_x, s_y, U_G, C_star):
x_s7, uw_s7, U_h0_s7 = calculate_wind_speed(0, 10000, 30001, 100, 100, 0.8, 7, 7, 10.0)
x_s8, uw_s8, U_h0_s8 = calculate_wind_speed(0, 10000, 30001, 100, 100, 0.8, 8, 8, 10.0)
x_s9, uw_s9, U_h0_s9 = calculate_wind_speed(0, 10000, 30001, 100, 100, 0.8, 9, 9, 10.0)
x_s10, uw_s10, U_h0_s10 = calculate_wind_speed(0, 10000, 30001, 100, 100, 0.8, 10, 10, 10.0)

plt.figure(figsize=(18, 6))
plt.axhline(y=10.0, color='purple', linestyle='--', label='U_h0')
plt.plot(x_s7, uw_s7, label='s = 7', color='#1f77b4')
plt.plot(x_s8, uw_s8, label='s = 8', color='#ff7f0e')
plt.plot(x_s9, uw_s9, label='s = 9', color='#2ca02c')
plt.plot(x_s10, uw_s10, label='s = 10', color='#d62728')

# Add text boxes for minimum wind velocities
min_s7 = np.nanmin(uw_s7)
min_s8 = np.nanmin(uw_s8)
min_s9 = np.nanmin(uw_s9)
min_s10 = np.nanmin(uw_s10)

plt.text(11300, min_s7, f"Min: {min_s7:.2f} m/s", color='#1f77b4', fontsize=14)
plt.text(11300, min_s8 + 0.08, f"Min: {min_s8:.2f} m/s", color='#ff7f0e', fontsize=14)
plt.text(11300, min_s9 + 0.16, f"Min: {min_s9:.2f} m/s", color='#2ca02c', fontsize=14)
plt.text(11300, min_s10 + 0.26, f"Min: {min_s10:.2f} m/s", color='#d62728', fontsize=14)

plt.xlabel('Downstream distance [m]')
plt.ylabel('Wind speed [m/s]')
plt.ylim(7.0, 10.5)
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
from sympy import symbols, limit, oo, ln

x1 = 0
x2 = 10000
x3 = 30000

z_h = 100
D = 100
s_x = 10
s_y = 10
C_T = 0.8
U_G = 11.87
C_star = 4.5

f = 1*10**(-4) # Coriolis parameter [1/s]
k = 0.4 # Von Karman constant [-]
z_0lo = 0.0001 # surface rughness length [m]

ct = (np.pi * C_T * D**2)/(8 * s_x*D * s_y*D)
print("ct: ", ct)
nu_star = 28 * np.sqrt(ct)
print("nu_star: ", nu_star)
beta =  nu_star / (1 + nu_star)
print("beta: ", beta)
z_0hi = z_h * (1 + D/(2 * z_h))**beta * np.exp(-(ct/(2 * k**2) + (np.log(z_h / z_0lo * (1 - D/(2 * z_h))**beta))**-2)**-0.5)
print("z_0hi: ", z_0hi)
u_star_lo = (k * U_G) / (np.log(U_G / (f * z_0lo)) - C_star)
print("u_star_lo: ", u_star_lo)
u_star_hi = (k * U_G) / (np.log(U_G / (f * z_0hi)) - C_star)
print("u_star_hi: ", u_star_hi)
U_h0 = u_star_lo / k * np.log(z_h / z_0lo)
print("U_h0: ", U_h0)
z0_WF = z_h * (1 + D/(2 * z_h))**beta * np.exp(-k * (ct + (k/np.log((z_h / z_0lo) * (1 - D/(2 * z_h))**beta))**2)**-0.5)
print("z0_WF: ", z0_WF)

from sympy import symbols, limit, oo, ln, sqrt, pi

x = symbols('x')

h1 = z_h + (x / z0_WF)**(4/5)
h2 = ((x - x2)/z0_WF)**(4/5)

# Use SymPy's ln(), not np.log()
uw_deficit = U_h0 * (ln(h1 / z_0lo) * ln(z_h / z0_WF)) / (ln(h1 / z0_WF) * ln(z_h/z_0lo))
uw_recovery = U_h0 * (ln(h1 / z_0lo) * ln(h2 / z0_WF)) / (ln(h1 / z0_WF) * ln(h2 / z_0lo))

# Take the limit as x → ∞
lim_inf = limit(uw_deficit, x, 0)
print("Limit as x → 0:", round(lim_inf,0))

# Take the limit as x → ∞
lim_inf = limit(uw_deficit, x, oo)
print("Limit as x → ∞:", round(lim_inf,0))
# Out:
# ct:  0.003141592653589793
# nu_star:  1.56939754059142
# beta:  0.6108037062377581
# z_0hi:  0.040470497524118396
# u_star_lo:  0.28960587639689944
# u_star_hi:  0.45691028954745894
# U_h0:  10.002632607524651
# z0_WF:  0.23568827613865057
# Limit as x → 0: 10.0000000000000
# Limit as x → ∞: 4.00000000000000

# %% [markdown]
# ## Model comparison to BGD

# %%
diameters = [200, 400, 600, 800, 1000]  # diameters downstream

# Wind velocities from BGD Propagate Downstream
velocities_2_5D = [8.822, 9.289, 9.485, 9.596, 9.668]
velocities_7D   = [9.695, 9.846, 9.892, 9.916, 9.932]
velocities_10D  = [9.825, 9.915, 9.941, 9.954, 9.963]

# Wind velocities from TDM IBL Recovery
TDM_2_5D = [7.006, 7.605, 8.464, 8.875, 9.116]
TDM_7D   = [9.446, 9.788, 9.872, 9.909, 9.930]
TDM_10D  = [9.733, 9.900, 9.941, 9.959, 9.969]

# Deviations [%] between BGD and TDM for each spacing
deviation_2_5D = [20.585, 18.129, 10.764, 7.514, 5.710]
deviation_7D   = [2.568, 0.589, 0.202, 0.202, 0.202]
deviation_10D  = [0.936, 0.151, 0.000, 0.050, 0.060]

# Plot wind velocities as a function of park lengths
plt.figure(figsize=(12, 5))
plt.plot(diameters, velocities_2_5D/U_h0, label=r'$BGD \; s = 2.5\;D$', color='#1f77b4')
plt.plot(diameters, velocities_7D/U_h0, label=r'$BGD \; s = 7\;D$', color='#ff7f0e')
plt.plot(diameters, velocities_10D/U_h0, label=r'$BGD \; s = 10\;D$', color='#2ca02c')
plt.plot(diameters, TDM_2_5D/U_h0, label=r'$TDM \; s = 2.5\;D$', linestyle='--', color='#1f77b4')
plt.plot(diameters, TDM_7D/U_h0, label=r'$TDM \; s = 7\;D$', linestyle='--', color='#ff7f0e')
plt.plot(diameters, TDM_10D/U_h0, label=r'$TDM \; s = 10\;D$', linestyle='--', color='#2ca02c')
plt.xlabel(r'$x \; [D]$')
plt.ylabel(r'$U \; / \; U_0$')
plt.legend()
plt.grid(True)
plt.show()

# Plot deviations as a function of park lengths
plt.figure(figsize=(12, 5))
plt.plot(diameters, deviation_2_5D/U_h0, label=r'$s = 2.5\;D$', marker='o')
plt.plot(diameters, deviation_7D/U_h0, label=r'$s = 7\;D$', marker='o')
plt.plot(diameters, deviation_10D/U_h0, label=r'$s = 10\;D$', marker='o')
plt.xlabel(r'$x \; [D]$')
plt.ylabel(r'$Deviation \; [\%]$')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# $ w_{width} = ((n-1) \cdot D \cdot s_y \cdot 1.08) + (0.04 + 0.01 \cdot s_y) \cdot x $
# ## Fit til efter alle wake er mixet
# ## Lav faktorer baseret på wake og ikke waket area?

# %%
# Park width calculation
s_x =10
n = 20
D = 100  # rotor diameter
x = np.linspace(160*D, 560*D, 6)

s7_ww = np.array([16282, 17180, 18016, 18810, 19570, 20302]) / D
s8_ww = np.array([18496, 19488, 20410, 21280, 22108, 22904]) / D
s9_ww = np.array([20700, 21782, 22782, 23720, 24612, 25466]) / D
s10_ww = np.array([22896, 24062, 25132, 26134, 27084, 27988]) / D

b = 0.06
a = 0.0065

s_x7 = 7
k7 = b + a * s_x7
wf7 = (n-1) * D*s_x7 * 1.1

s_x8 = 8
k8 = b + a *s_x8
wf8 = (n-1) * D*s_x8 * 1.1

s_x9 = 9
k9 = b + a *s_x9
wf9 = (n-1) * D*s_x9 * 1.1

s_x10 = 10
k10 = b + a *s_x10
wf10 = (n-1) * D*s_x10 * 1.1

ww_s7 = (wf7 + k7 * x) / D
print(ww_s7)
ww_s8 = (wf8 + k8 * x) / D
print(ww_s8)
ww_s9 = (wf9 + k9 * x) / D
print(ww_s9)
ww_s10 = (wf10 + k10 * x) / D
print(ww_s10)

plt.figure(figsize=(12, 5))
plt.plot(x/D, s7_ww, label=r'$BGD \; s = 7\,D$', color='#1f77b4')
plt.plot(x/D, s8_ww, label=r'$BGD \; s = 8\,D$', color='#ff7f0e')
plt.plot(x/D, s9_ww, label=r'$BGD \; s = 9\,D$', color='#2ca02c')
plt.plot(x/D, s10_ww, label=r'$BGD \; s = 10\,D$', color='#d62728')

plt.plot(x/D, ww_s7, label=r'$Linear \; s = 7\,D$', linestyle='--', color='#1f77b4')
plt.plot(x/D, ww_s8, label=r'$Linear \; s = 8\,D$', linestyle='--', color='#ff7f0e')
plt.plot(x/D, ww_s9, label=r'$Linear \; s = 9\,D$', linestyle='--', color='#2ca02c')
plt.plot(x/D, ww_s10, label=r'$Linear \;  s = 10\,D$', linestyle='--', color='#d62728')
plt.xlabel(r'$x \; [D]$')
plt.ylabel(r'$y \; [D]$')
plt.xlim(200, 560)
plt.ylim(160, 340)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [163.18 171.62 180.06 188.5  196.94 205.38]
# [185.12 194.08 203.04 212.   220.96 229.92]
# [207.06 216.54 226.02 235.5  244.98 254.46]
# [229. 239. 249. 259. 269. 279.]
